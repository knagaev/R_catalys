# %%
import pandas as pd

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from distutils.version import LooseVersion

print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
def add_worksheet(df, excel_file_name, sheet_name):
  book = load_workbook(excel_file_name)
  writer = pd.ExcelWriter(excel_file_name, engine='openpyxl') 
  writer.book = book
  writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

  df.to_excel(writer, sheet_name, index=True)
  writer.save()
  del df

# %%
source_file_name = r'C:\PLR\catalys\calibration\ГПН_Ароформинг_Сила_PS_PO_ver_0_2.xlsx'

# %%
with pd.ExcelFile(source_file_name) as xls_source_file:
  df_ps = pd.read_excel(xls_source_file, 'PS_Strength')  # PS (красная - ведущая)
  df_po = pd.read_excel(xls_source_file, 'PO_Strength')  # PO (зеленая)

df_ps.dropna(subset=['Basic publication number'], inplace=True)
df_po.dropna(subset=['Earliest publication number'], inplace=True)

df_ps.set_index('Basic publication number', inplace=True)
df_po.set_index('Earliest publication number', inplace=True)

# %%
df_ps.head()
# Out:
#                                                              Family members  \
# Basic publication number
# AU5147401.A                         AU5147401.A; EP1272446.A1; WO0177046.A1
# AU9116801.A                         AU9116801.A; US6506954.B1; WO0232837.A1
# CA1175073.A               AU8867482.A; CA1175073.A; DE3236093.A1; JPS585...
# CA1286321.C                                                     CA1286321.C
# CN101244969.A                                  CN101244969.A; CN101244969.B
#
#                           Technology Relevance™  Market Coverage™  \
# Basic publication number
# AU5147401.A                            0.380912          0.000000
# AU9116801.A                            1.857973          0.000000
# CA1175073.A                            0.785944          0.000000
# CA1286321.C                            0.143199          0.000000
# CN101244969.A                          3.466704          0.634496
#
#                           Competitive Impact™  Patent Asset Index™  \
# Basic publication number
# AU5147401.A                           0.00000              0.00000
# AU9116801.A                           0.00000              0.00000
# CA1175073.A                           0.00000              0.00000
# CA1286321.C                           0.00000              0.00000
# CN101244969.A                         2.19961              2.19961
#
#                           Total number of citations received Priority date  \
# Basic publication number
# AU5147401.A                                              3.0    2000-04-11
# AU9116801.A                                             31.0    2000-04-11
# CA1175073.A                                              3.0    1981-09-29
# CA1286321.C                                              0.0    1985-06-27
# CN101244969.A                                           24.0    2008-03-25
#
#                           IPC Level 3 - Total no. of assigned IPC subclasses  \
# Basic publication number
# AU5147401.A                                                             1.0
# AU9116801.A                                                             1.0
# CA1175073.A                                                             3.0
# CA1286321.C                                                             1.0
# CN101244969.A                                                           2.0
#
#                           INPADOC family ID  \
# Basic publication number
# AU5147401.A                       1376028.0
# AU9116801.A                       1376028.0
# CA1175073.A                       2417614.0
# CA1286321.C                        514124.0
# CN101244969.A                    55181421.0
#
#                                                     Citing patents by owner  \
# Basic publication number
# AU5147401.A               Tsinghua University (China) (CN101823929.A); E...
# AU9116801.A               Exxon Mobil (US2015175897.A1, US9790139.B2, US...
# CA1175073.A               JXTG Holdings (JP2011184572.A); Toyo Engineeri...
# CA1286321.C                                                             NaN
# CN101244969.A             Sinopec Group (US9339801.B2, CN105985209.A, EP...
#
#                           ... Unnamed: 113 Unnamed: 114 Unnamed: 115  \
# Basic publication number  ...
# AU5147401.A               ...          NaN          NaN          NaN
# AU9116801.A               ...          NaN          NaN          NaN
# CA1175073.A               ...          NaN          NaN          NaN
# CA1286321.C               ...          NaN          NaN          NaN
# CN101244969.A             ...          NaN          NaN          NaN
#
#                          Unnamed: 116 Unnamed: 117 Unnamed: 118 Unnamed: 119  \
# Basic publication number
# AU5147401.A                       NaN          NaN          NaN          NaN
# AU9116801.A                       NaN          NaN          NaN          NaN
# CA1175073.A                       NaN          NaN          NaN          NaN
# CA1286321.C                       NaN          NaN          NaN          NaN
# CN101244969.A                     NaN          NaN          NaN          NaN
#
#                          Unnamed: 120 Unnamed: 121 Unnamed: 122
# Basic publication number
# AU5147401.A                       NaN          NaN          NaN
# AU9116801.A                       NaN          NaN          NaN
# CA1175073.A                       NaN          NaN          NaN
# CA1286321.C                       NaN          NaN          NaN
# CN101244969.A                     NaN          NaN          NaN
#
# [5 rows x 122 columns]

# %%
df_po.head()
# Out:
#                                                                 Family members  \
# Earliest publication number
# AU2009273843                 WO2010011958\r\nCA2731837\r\nAU2009273843\r\nU...
# AU3162484                    AU3162484\r\nEP0134058\r\nZA8406063\r\nJPS6053...
# AU6980581                    AU6980581\r\nEP0039996\r\nGB2075357\r\nJPS5742...
# AU7010381                    AU7010381\r\nEP0039964\r\nNL8002582\r\nJPS5722...
# AU7131481                    AU7131481\r\nGB2077709\r\nGB2077709\r\nNZ19729...
#
#                              Soundness  Novelty  Breadth  \
# Earliest publication number
# AU2009273843                      0.00     0.04    0.060
# AU3162484                         0.04     0.01    0.085
# AU6980581                         0.04     0.01    0.060
# AU7010381                         0.04     0.01    0.085
# AU7131481                         0.04     0.01    0.085
#
#                              Focus of leading companies  \
# Earliest publication number
# AU2009273843                                        0.0
# AU3162484                                           0.0
# AU6980581                                           0.0
# AU7010381                                           0.0
# AU7131481                                           0.0
#
#                              Focus of leading countries  Lexis Alternative  \
# Earliest publication number
# AU2009273843                                        0.0              0.208
# AU3162484                                           0.0              0.216
# AU6980581                                           0.0              0.168
# AU7010381                                           0.0              0.170
# AU7131481                                           0.0              0.208
#
#                              Assignee-Leader (Coefficient) (leader = 1;\nnot a leader = 0)  \
# Earliest publication number
# AU2009273843                                                               0.0
# AU3162484                                                                  0.0
# AU6980581                                                                  0.0
# AU7010381                                                                  0.0
# AU7131481                                                                  0.0
#
#                              Family Patent  Total  \
# Earliest publication number
# AU2009273843                          0.05  0.258
# AU3162484                             0.05  0.266
# AU6980581                             0.05  0.218
# AU7010381                             0.05  0.220
# AU7131481                             0.05  0.258
#
#                                                                     Kind codes  \
# Earliest publication number
# AU2009273843                 A2\r\nA1\r\nA1\r\nA1\r\nA3\r\nA2\r\nA\r\nA\r\n...
# AU3162484                    A\r\nA2\r\nB\r\nA\r\nA3\r\nA\r\nB2\r\nA\r\nB1\...
# AU6980581                             A\r\nA1\r\nA\r\nA\r\nA\r\nB1\r\nD1\r\nB2
# AU7010381                    A\r\nA1\r\nA\r\nA\r\nA\r\nB\r\nA\r\nA\r\nB1\r\...
# AU7131481                           A\r\nA\r\nB\r\nA\r\nB2\r\nA\r\nA\r\nA\r\nA
#
#                             Earliest publication country  \
# Earliest publication number
# AU2009273843                                          AU
# AU3162484                                             AU
# AU6980581                                             AU
# AU7010381                                             AU
# AU7131481                                             AU
#
#                                                              Current assignees  \
# Earliest publication number
# AU2009273843                                     CONOCOPHILLIPS\r\nPHILLIPS 66
# AU3162484                    SHELL\r\nSHELL CANADA\r\nSHELL INTERNATIONALE ...
# AU6980581                                                        COAL INDUSTRY
# AU7010381                    SHELL\r\nSHELL CANADA\r\nSHELL INTERNATIONALE ...
# AU7131481                                   ICI - IMPERIAL CHEMICAL INDUSTRIES
#
#                              Assignee standartization
# Earliest publication number
# AU2009273843                                      NaN
# AU3162484                                         NaN
# AU6980581                                         NaN
# AU7010381                                         NaN
# AU7131481                                         NaN

# %%
# выделяем в наименованиях базовых публикаций PS (красная - ведущая) основную и суффиксную часть
df_ps_prepared = df_ps.reset_index()

df_ps_prepared = df_ps_prepared.join(
    df_ps_prepared['Basic publication number'].str
        .split('.', n=1, expand=True)
        .rename(columns={0:'Basic publication number main', 1:'Basic publication number suffix'}))

df_ps_prepared.head()
# Out:
#   Basic publication number                                     Family members  \
# 0              AU5147401.A            AU5147401.A; EP1272446.A1; WO0177046.A1
# 1              AU9116801.A            AU9116801.A; US6506954.B1; WO0232837.A1
# 2              CA1175073.A  AU8867482.A; CA1175073.A; DE3236093.A1; JPS585...
# 3              CA1286321.C                                        CA1286321.C
# 4            CN101244969.A                       CN101244969.A; CN101244969.B
#
#    Technology Relevance™  Market Coverage™  Competitive Impact™  \
# 0               0.380912          0.000000              0.00000
# 1               1.857973          0.000000              0.00000
# 2               0.785944          0.000000              0.00000
# 3               0.143199          0.000000              0.00000
# 4               3.466704          0.634496              2.19961
#
#    Patent Asset Index™  Total number of citations received Priority date  \
# 0              0.00000                                 3.0    2000-04-11
# 1              0.00000                                31.0    2000-04-11
# 2              0.00000                                 3.0    1981-09-29
# 3              0.00000                                 0.0    1985-06-27
# 4              2.19961                                24.0    2008-03-25
#
#    IPC Level 3 - Total no. of assigned IPC subclasses  INPADOC family ID  ...  \
# 0                                                1.0           1376028.0  ...
# 1                                                1.0           1376028.0  ...
# 2                                                3.0           2417614.0  ...
# 3                                                1.0            514124.0  ...
# 4                                                2.0          55181421.0  ...
#
#   Unnamed: 115 Unnamed: 116 Unnamed: 117 Unnamed: 118 Unnamed: 119  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 120 Unnamed: 121 Unnamed: 122 Basic publication number main  \
# 0          NaN          NaN          NaN                     AU5147401
# 1          NaN          NaN          NaN                     AU9116801
# 2          NaN          NaN          NaN                     CA1175073
# 3          NaN          NaN          NaN                     CA1286321
# 4          NaN          NaN          NaN                   CN101244969
#
#   Basic publication number suffix
# 0                               A
# 1                               A
# 2                               A
# 3                               C
# 4                               A
#
# [5 rows x 125 columns]

# %%
# проверка на уникальность 'Basic publication number main'
df_ps_bpnm_more_than_one = df_ps_prepared.groupby('Basic publication number main').filter(lambda x: len(x) > 1)

if len(df_ps_bpnm_more_than_one) > 0:
    raise ValueError("Дубликаты в 'Basic publication number main'")

df_ps_prepared.set_index(['Basic publication number main'], inplace=True)
    
df_ps_prepared.head()
# Out:
#                               Basic publication number  \
# Basic publication number main
# AU5147401                                  AU5147401.A
# AU9116801                                  AU9116801.A
# CA1175073                                  CA1175073.A
# CA1286321                                  CA1286321.C
# CN101244969                              CN101244969.A
#
#                                                                   Family members  \
# Basic publication number main
# AU5147401                                AU5147401.A; EP1272446.A1; WO0177046.A1
# AU9116801                                AU9116801.A; US6506954.B1; WO0232837.A1
# CA1175073                      AU8867482.A; CA1175073.A; DE3236093.A1; JPS585...
# CA1286321                                                            CA1286321.C
# CN101244969                                         CN101244969.A; CN101244969.B
#
#                                Technology Relevance™  Market Coverage™  \
# Basic publication number main
# AU5147401                                   0.380912          0.000000
# AU9116801                                   1.857973          0.000000
# CA1175073                                   0.785944          0.000000
# CA1286321                                   0.143199          0.000000
# CN101244969                                 3.466704          0.634496
#
#                                Competitive Impact™  Patent Asset Index™  \
# Basic publication number main
# AU5147401                                  0.00000              0.00000
# AU9116801                                  0.00000              0.00000
# CA1175073                                  0.00000              0.00000
# CA1286321                                  0.00000              0.00000
# CN101244969                                2.19961              2.19961
#
#                                Total number of citations received  \
# Basic publication number main
# AU5147401                                                     3.0
# AU9116801                                                    31.0
# CA1175073                                                     3.0
# CA1286321                                                     0.0
# CN101244969                                                  24.0
#
#                               Priority date  \
# Basic publication number main
# AU5147401                        2000-04-11
# AU9116801                        2000-04-11
# CA1175073                        1981-09-29
# CA1286321                        1985-06-27
# CN101244969                      2008-03-25
#
#                                IPC Level 3 - Total no. of assigned IPC subclasses  \
# Basic publication number main
# AU5147401                                                                    1.0
# AU9116801                                                                    1.0
# CA1175073                                                                    3.0
# CA1286321                                                                    1.0
# CN101244969                                                                  2.0
#
#                                INPADOC family ID  ... Unnamed: 114  \
# Basic publication number main                     ...
# AU5147401                              1376028.0  ...          NaN
# AU9116801                              1376028.0  ...          NaN
# CA1175073                              2417614.0  ...          NaN
# CA1286321                               514124.0  ...          NaN
# CN101244969                           55181421.0  ...          NaN
#
#                               Unnamed: 115 Unnamed: 116 Unnamed: 117  \
# Basic publication number main
# AU5147401                              NaN          NaN          NaN
# AU9116801                              NaN          NaN          NaN
# CA1175073                              NaN          NaN          NaN
# CA1286321                              NaN          NaN          NaN
# CN101244969                            NaN          NaN          NaN
#
#                               Unnamed: 118 Unnamed: 119 Unnamed: 120  \
# Basic publication number main
# AU5147401                              NaN          NaN          NaN
# AU9116801                              NaN          NaN          NaN
# CA1175073                              NaN          NaN          NaN
# CA1286321                              NaN          NaN          NaN
# CN101244969                            NaN          NaN          NaN
#
#                               Unnamed: 121 Unnamed: 122  \
# Basic publication number main
# AU5147401                              NaN          NaN
# AU9116801                              NaN          NaN
# CA1175073                              NaN          NaN
# CA1286321                              NaN          NaN
# CN101244969                            NaN          NaN
#
#                               Basic publication number suffix
# Basic publication number main
# AU5147401                                                   A
# AU9116801                                                   A
# CA1175073                                                   A
# CA1286321                                                   C
# CN101244969                                                 A
#
# [5 rows x 124 columns]

# %%
# семейства в PO (зелёная - ведомая)
df_po_families = df_po['Family members'].str.split('\r\n', expand=True).stack() \
    .str.strip().reset_index(level=0, drop=False).drop_duplicates()
df_po_families.columns = ['Earliest publication number', 'Family member']
df_po_families.head()
# Out:
#   Earliest publication number  Family member
# 0                AU2009273843   WO2010011958
# 1                AU2009273843      CA2731837
# 2                AU2009273843   AU2009273843
# 3                AU2009273843  US20100041932
# 5                AU2009273843      EP2313193

# %%
#df_po_ps_mapping.groupby(['Basic publication number', 'Earliest publication number'])\
#  .size().reset_index()#.sort_values(by=['col1'])

# %%
#df_po_ps_grouped = df_po_ps_mapping.groupby(['Earliest publication number', 'Basic publication number']).count()

#result_file_name = r'C:\PLR\catalys\calibration\result.xlsx'
#writer = pd.ExcelWriter(result_file_name)
#df_po_ps_grouped.to_excel(writer, 'df_po_ps_grouped')
#writer.save()

# %%
# соответствие базовых документов в po_strength документам из семейств в ps_strength
#df = df_ps_families.apply(lambda row: \
#  df_po['Family members'].get(row.index.get_level_values('Family member base'), None), axis=1).to_frame()
#df.columns

# %%
# соответствие базовых документов в po_strength документам из семейств в ps_strength
#df_ps_families.apply(lambda row: \
#  df_po['Family members'].get(row.index.get_level_values('Family member base'), None), axis=1)

# %%
# ищем записи, где в семействе нет базовой публикации (и добавляем её в семейство)
# старая версия

#df_po_families_merged = df_po_families.merge(df_po_families, how='left', 
#  left_on='Earliest publication number', right_on='Family member', indicator=True).sort_values(['_merge'])

#df_po_families_merged.loc[(df_po_families_merged['_merge']=='left_only') 
#                      & df_po_families_merged['Family member_x'].str.startswith('US')
#                     , ['Earliest publication number_x', 'Earliest publication number_x']].head(20)

# %%
#ищем записи, где в семействе нет базовой публикации (и добавляем её в семейство)
family_members = df_po_families['Family member']

df_earliest_not_in_family = df_po_families.loc[~df_po_families['Earliest publication number'].isin(family_members), ['Earliest publication number', 'Earliest publication number']]
df_earliest_not_in_family.columns = ['Earliest publication number', 'Family member']

#df_earliest_not_in_family.head()

df_po_families = pd.concat([df_po_families, df_earliest_not_in_family])

df_po_families.set_index(['Family member'], inplace=True)

df_po_families
# Out:
#               Earliest publication number
# Family member
# WO2010011958                 AU2009273843
# CA2731837                    AU2009273843
# AU2009273843                 AU2009273843
# US20100041932                AU2009273843
# EP2313193                    AU2009273843
# ...                                   ...
# US08569557                     US08569557
# US08569558                     US08569558
# US08569558                     US08569558
# US08569558                     US08569558
# US08569558                     US08569558
#
# [1064 rows x 1 columns]

# %%
df_ps_po = df_ps_prepared.merge(df_po_families, left_index=True, right_index=True).merge(df_po, left_on='Earliest publication number', right_index=True, suffixes=('_ps', '_po'))

# %%
df_ps_po.loc[:, ['Basic publication number', 'Family members_ps', 'Family members_po', 'Earliest publication number']].head()
# Out:
#           Basic publication number  \
# AU5147401              AU5147401.A
# AU9116801              AU9116801.A
# CA1175073              CA1175073.A
# CA1286321              CA1286321.C
# US4709114              US4709114.A
#
#                                            Family members_ps  \
# AU5147401            AU5147401.A; EP1272446.A1; WO0177046.A1
# AU9116801            AU9116801.A; US6506954.B1; WO0232837.A1
# CA1175073  AU8867482.A; CA1175073.A; DE3236093.A1; JPS585...
# CA1286321                                        CA1286321.C
# US4709114                                        US4709114.A
#
#                                            Family members_po  \
# AU5147401  WO200177046\r\nAU5147401\r\nEP1272446\r\nUS650...
# AU9116801                           WO200232837\r\nAU9116801
# CA1175073  JPS5857494\r\nDE3236093\r\nAU8867482\r\nCA1175073
# CA1286321                             US4709114\r\nCA1286321
# US4709114                             US4709114\r\nCA1286321
#
#           Earliest publication number
# AU5147401                 WO200177046
# AU9116801                 WO200232837
# CA1175073                  JPS5857494
# CA1286321                  US04709114
# US4709114                  US04709114

# %%
po_ps_columns = ['Basic publication number', 'Family members_ps', 'Family members_po', 'Earliest publication number', 'Technology Relevance™', 'Market Coverage™', 'Competitive Impact™', 'Patent Asset Index™', 'Total number of citations received', 'Soundness', 'Novelty', 'Breadth', 'Focus of leading companies', 'Focus of leading countries']
df_source = df_ps_po.loc[:, po_ps_columns].sort_values('Basic publication number')
df_source.head()
# Out:
#             Basic publication number  \
# AU5147401                AU5147401.A
# AU9116801                AU9116801.A
# CA1175073                CA1175073.A
# CA1286321                CA1286321.C
# CN101244969            CN101244969.A
#
#                                              Family members_ps  \
# AU5147401              AU5147401.A; EP1272446.A1; WO0177046.A1
# AU9116801              AU9116801.A; US6506954.B1; WO0232837.A1
# CA1175073    AU8867482.A; CA1175073.A; DE3236093.A1; JPS585...
# CA1286321                                          CA1286321.C
# CN101244969                       CN101244969.A; CN101244969.B
#
#                                              Family members_po  \
# AU5147401    WO200177046\r\nAU5147401\r\nEP1272446\r\nUS650...
# AU9116801                             WO200232837\r\nAU9116801
# CA1175073    JPS5857494\r\nDE3236093\r\nAU8867482\r\nCA1175073
# CA1286321                               US4709114\r\nCA1286321
# CN101244969                         CN101244969\r\nCN101244969
#
#             Earliest publication number  Technology Relevance™  \
# AU5147401                   WO200177046               0.380912
# AU9116801                   WO200232837               1.857973
# CA1175073                    JPS5857494               0.785944
# CA1286321                    US04709114               0.143199
# CN101244969                 CN101244969               3.466704
#
#              Market Coverage™  Competitive Impact™  Patent Asset Index™  \
# AU5147401            0.000000              0.00000              0.00000
# AU9116801            0.000000              0.00000              0.00000
# CA1175073            0.000000              0.00000              0.00000
# CA1286321            0.000000              0.00000              0.00000
# CN101244969          0.634496              2.19961              2.19961
#
#              Total number of citations received  Soundness  Novelty  Breadth  \
# AU5147401                                   3.0       0.00     0.04    0.005
# AU9116801                                  31.0       0.00     0.04    0.005
# CA1175073                                   3.0       0.04     0.01    0.060
# CA1286321                                   0.0       0.04     0.01    0.060
# CN101244969                                24.0       0.04     0.04    0.020
#
#              Focus of leading companies  Focus of leading countries
# AU5147401                           0.2                       0.010
# AU9116801                           0.2                       0.010
# CA1175073                           0.0                       0.000
# CA1286321                           0.2                       0.010
# CN101244969                         0.0                       0.008

# %%
X = df_source[['Soundness', 'Novelty', 'Breadth', 'Focus of leading companies', 'Focus of leading countries']].values
y = df_source['Competitive Impact™'].values

# %%
#df_po_ps_mapping.sort_values(by=['Basic publication number', 'Earliest publication number'])

#result_file_name = r'C:\PLR\catalys\calibration\result.xlsx'
#writer = pd.ExcelWriter(result_file_name)
#df_po_ps_mapping.sort_values(by=['Basic publication number', 'Earliest publication number'])\
#  .to_excel(writer, 'df_po_ps_sorted')
#writer.save()

# %%
from sklearn.preprocessing import StandardScaler

sc_x = StandardScaler()
sc_y = StandardScaler()

X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y.reshape(-1, 1)).flatten()

# %%
f, (ax0, ax1) = plt.subplots(1, 2)

ax0.hist(y, bins=100, **density_param)
ax0.set_ylabel('Probability')
ax0.set_xlabel('Target')
ax0.set_title('Target distribution')

ax1.hist(y_std, bins=100, **density_param)
ax1.set_ylabel('Probability')
ax1.set_xlabel('Target')
ax1.set_title('Transformed target distribution')

f.suptitle("Calibration data: Competitive Impact", y=0.035)
f.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()

slr.fit(X_train, y_train)

y_train_pred = slr.predict(X_train)
y_test_pred = slr.predict(X_test)

# %%
slr.coef_
# Out:
# array([-1.31510147,  3.76640028,  8.94417715, -1.32916924, 57.73716914])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score

print('MSE train: {:.3f}, test: {:.3f}'.format(
        mean_squared_error(y_train, y_train_pred),
        mean_squared_error(y_test, y_test_pred)))
print('R^2 train: {:.3f}, test: {:.3f}'.format(
        r2_score(y_train, y_train_pred),
        r2_score(y_test, y_test_pred)))
# Out:
# MSE train: 1.008, test: 3.425
# R^2 train: 0.100, test: 0.003
